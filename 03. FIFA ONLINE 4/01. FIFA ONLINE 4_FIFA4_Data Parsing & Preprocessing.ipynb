# %%
import json # Json Object Array 이용
import requests # 호출 위함
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pickle
import datetime as dt
from tqdm.notebook import tqdm
from IPython.display import Image # 주피터 노트북에 이미지 삽입

# 폰트 설정
mpl.rc('font', family='New Gulim')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %matplotlib inline

pd.set_option('max_columns', 100) # To see 50 columns
pd.set_option('max_rows', 100) # To see 100 rows

# %%
data = pd.DataFrame({'matchInfo': [{'key1': 'value1', 'key2': 'value2'}, {'key1': 'value3', 'key2': 'value4'}]})

# %%
api_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiNzcxOTk2MDk0IiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3NDcxNDg2MjcsImlhdCI6MTY4NDA3NjYyNywibmJmIjoxNjg0MDc2NjI3LCJzZXJ2aWNlX2lkIjoiNDMwMDExNDgxIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.I6RWrB_IWECckV4cRB49I45J0ES1Mbz5beSJA3tZF58"
user_params = {'nickname' : '챔피언스국대'}

# %%
headers = {'Authorization' : api_key}
user_params = {'nickname' : '챔피언스국대'} # 피파온라인4 닉네임
user_info_url = requests.get('https://api.nexon.co.kr/fifaonline4/v1.0/users?', \
                             params = user_params, headers = headers)
user_parsed_data = user_info_url.json()
user_info_data = pd.DataFrame(user_parsed_data, index = [0])
user_info_data
# Out:
#                    accessId nickname  level
# 0  3cdf995d54068517228c31cd   챔피언스국대    712

# %%
headers = {'Authorization' : api_key} 
match_params = {'matchtype' : 50, 'offset' : 0, 'limit' : 100}
match_record_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/users/3cdf995d54068517228c31cd/matches?',\
                                params=match_params, headers = headers)
match_record_parsed_data = match_record_url.json()
print(match_record_parsed_data) # 총 100건의 매치 조회
# Out:
# ['6463880b82e1730114777f16', '646239e2206717b7ae7ac23d', '6460dbfd9fbc18bd9c7b47b9', '645fa8eba5540d06b82cee79', '645fa619b2d22df08adb9637', '645f96b1178e1cc31b9cedc5', '645f941668a67a9185e8e3e2', '645f9130826d0d7a311c101a', '645e61a72220eda601553205', '645e5f32e14adbfc48e50b0b', '645e5c07422c403ab0bf85af', '645e446597a6d2171fd7349c', '645791a482f29357650ded5a', '64571afafe6bb3b9d875b256', '645717fc31e478ca6652d90e', '64570b53a5527f6fcb48b47c', '6455c76ab20bcf42d6bfba48', '6455c4918b7f360262da0279', '6455c1e89da27545ca226844', '64545b41866bb6ca2105b5ac', '645458a6b9312155f363e074', '644fb3d6a2b7c92db092e2d6', '644f307313029ed97e2a246e', '644f2dc2f663e8f2e004ec17', '644e4c5899229167f567a95d', '644e3bbe86d4d4409c273fa7', '644dd7eeae56f8fe69f50d97', '644dd28893595b948f0c11a9', '644dcff94a5285015087b82e', '644d4278dbf720aa52c0ddc2', '644d3fa34bc4a541780e9947', '644d3d3068b6fa5a85afab89', '644d3640932b4845b17fb5ba', '644d332375710c5e48ffc4fc', '644d31be4c1bdd4f3f84c4f7', '644d2f0204f88c97
# ...

# %%
# 매치 상세 기록 조회 데이터 부르기
my_match = pd.DataFrame()
for idx, match in tqdm(enumerate(match_record_parsed_data)):
    matchid = match_record_parsed_data[idx]
    match_detail_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}', headers = headers)
    match_detail_parsed_data = match_detail_url.json()
    temp = pd.DataFrame(match_detail_parsed_data)
    my_match = pd.concat([my_match, temp], axis = 0)
    
my_match # 매치 상세 기록 데이터
# Out:
# 0it [00:00, ?it/s]
#                      matchId            matchDate  matchType  \
# 0   6463880b82e1730114777f16  2023-05-16T22:51:22         50
# 1   6463880b82e1730114777f16  2023-05-16T22:51:22         50
# 0   646239e2206717b7ae7ac23d  2023-05-15T23:07:10         50
# 1   646239e2206717b7ae7ac23d  2023-05-15T23:07:10         50
# 0   6460dbfd9fbc18bd9c7b47b9  2023-05-14T22:13:28         50
# ..                       ...                  ...        ...
# 1   64381afe9c7665723adb2956  2023-04-14T00:19:30         50
# 0   64381a0cf41ad160d023ba29  2023-04-14T00:08:13         50
# 1   64381a0cf41ad160d023ba29  2023-04-14T00:08:13         50
# 0   6438178fa60ed958fbf52bf8  2023-04-14T00:04:14         50
# 1   6438178fa60ed958fbf52bf8  2023-04-14T00:04:14         50
#
#                                             matchInfo
# 0   {'accessId': '2e79630544e8b60b4e280106', 'nick...
# 1   {'accessId': '3cdf995d54068517228c31cd', 'nick...
# ...

# %% [markdown]
# Match Information
# - accessId : 유저 고유 식별자 (String)
# - nickname : 유저 닉네임 (String)
# - matchDetail : 매치 결과 상세 정보 (MatchDetailDTO)
# - shoot : 슈팅 정보 (ShootDTO)
# - shootDetail : 슈팅 별 상세정보 리스트 (Array)
# - pass : 패스 정보 (PassDTO)
# - defence : 수비 정보 (DefenceDTO)
# - player : 경기 사용 선수 정보 (Array)
# - 데이터 셋을 살펴보면 인덱스가 (0,1)로 묶여진 것을 확인할 수 있음
#   → 한 경기 내 2명의 유저 의미

# %%
# 인덱스 변경
plus_index = list()
for i in range(0, 100):
    temp1 = i
    temp2 = i
    plus_index.append(temp1)
    plus_index.append(temp2)

len(plus_index)
# Out:
# 200

# %%
my_match['change_index'] = plus_index
my_match = my_match.set_index('change_index', drop=True) # 인덱스 변경
my_match.head()
# Out:
#                                matchId            matchDate  matchType  \
# change_index
# 0             6463880b82e1730114777f16  2023-05-16T22:51:22         50
# 0             6463880b82e1730114777f16  2023-05-16T22:51:22         50
# 1             646239e2206717b7ae7ac23d  2023-05-15T23:07:10         50
# 1             646239e2206717b7ae7ac23d  2023-05-15T23:07:10         50
# 2             6460dbfd9fbc18bd9c7b47b9  2023-05-14T22:13:28         50
#
#                                                       matchInfo
# change_index
# 0             {'accessId': '2e79630544e8b60b4e280106', 'nick...
# 0             {'accessId': '3cdf995d54068517228c31cd', 'nick...
# 1             {'accessId': '3cdf995d54068517228c31cd', 'nick...
# 1             {'accessId': 'e7442b8debde3fbc6b39befe', 'nick...
# 2             {'accessId': '3cdf995d54068517228c31cd', 'nick...

# %%
# 첫 번째 데이터를 통해 어떤 형식으로 이루어져 있는가 확인해보자
matchid = match_record_parsed_data[0]
match_detail_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}', headers = headers)
match_detail_parsed_data = match_detail_url.json()
match_detail_parsed_data # 해당 데이터의 형태
# Out:
# {'matchId': '6463880b82e1730114777f16',
#  'matchDate': '2023-05-16T22:51:22',
#  'matchType': 50,
#  'matchInfo': [{'accessId': '2e79630544e8b60b4e280106',
#    'nickname': '낭만낭만낭만',
#    'matchDetail': {'seasonId': 202305,
#     'matchResult': '패',
#     'matchEndType': 0,
#     'systemPause': 1,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 91,
#     'cornerKick': 0,
#     'possession': 60,
#     'offsideCount': 0,
#     'averageRating': 3.70556,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 6,
#     'effectiveShootTotal': 4,
#     'shootOutScore': 0,
#     'goalTotal': 1,
#     'goalTotalDisplay': 1,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 4,
#     'goalInPenalty': 0,
#     'shootOutPenalty': 2,
#     'goalOutPenalty': 1,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
# ...

# %%
match_info_data = pd.DataFrame()
match_detail_data = pd.DataFrame()
match_shoot_data = pd.DataFrame()
match_pass_data = pd.DataFrame()
match_defence_data = pd.DataFrame()

# %%
pd.DataFrame(match_detail_parsed_data['matchInfo'])
# Out:
#                    accessId nickname  \
# 0  2e79630544e8b60b4e280106   낭만낭만낭만
# 1  3cdf995d54068517228c31cd   챔피언스국대
#
#                                          matchDetail  \
# 0  {'seasonId': 202305, 'matchResult': '패', 'matc...
# 1  {'seasonId': 202305, 'matchResult': '승', 'matc...
#
#                                                shoot  \
# 0  {'shootTotal': 6, 'effectiveShootTotal': 4, 's...
# 1  {'shootTotal': 5, 'effectiveShootTotal': 3, 's...
#
#                                          shootDetail  \
# 0  [{'goalTime': 1950, 'x': 0.8737162351608276, '...
# 1  [{'goalTime': 823, 'x': 0.8657850623130798, 'y...
#
#                                                 pass  \
# 0  {'passTry': 139, 'passSuccess': 125, 'shortPas...
# 1  {'passTry': 87, 'passSuccess': 76, 'shortPassT...
#
#                                              defence  \
# 0  {'blockTry': 6, 'blockSuccess': 1, 'tackleTry'...
# 1  {'blockTry': 7, 'blockSuccess': 1, 'tackleTry'...
#
# ...

# %%
# DTO 정보 리스트 형태로 만들기
accessId_list = [m.get('accessId') for m in match_HOJJIMIN['matchInfo']]
nickname_list = [m.get('nickname') for m in match_HOJJIMIN['matchInfo']]
matchDetail_list = [m.get('matchDetail') for m in match_HOJJIMIN['matchInfo']]
shootDetail_list = [m.get('shoot') for m in match_HOJJIMIN['matchInfo']]
passDetail_list = [m.get('pass') for m in match_HOJJIMIN['matchInfo']]
defenceDetail_list = [m.get('defence') for m in match_HOJJIMIN['matchInfo']]

print('accessInfo 리스트 갯수 : ', len(accessId_list))
print('nicknameInfo 리스트 갯수 : ', len(nickname_list))
print('matchInfo 리스트 갯수 : ', len(matchDetail_list))
print('shoot 리스트 갯수 : ', len(shootDetail_list))
print('pass 리스트 갯수 : ', len(passDetail_list))
print('defence 리스트 갯수 : ', len( defenceDetail_list))
# Out:
# accessInfo 리스트 갯수 :  200
# nicknameInfo 리스트 갯수 :  200
# matchInfo 리스트 갯수 :  200
# shoot 리스트 갯수 :  200
# pass 리스트 갯수 :  200
# defence 리스트 갯수 :  200

# %%
my_match
# Out:
#                                matchId            matchDate  matchType  \
# change_index
# 0             6463880b82e1730114777f16  2023-05-16T22:51:22         50
# 0             6463880b82e1730114777f16  2023-05-16T22:51:22         50
# 1             646239e2206717b7ae7ac23d  2023-05-15T23:07:10         50
# 1             646239e2206717b7ae7ac23d  2023-05-15T23:07:10         50
# 2             6460dbfd9fbc18bd9c7b47b9  2023-05-14T22:13:28         50
# ...                                ...                  ...        ...
# 97            64381afe9c7665723adb2956  2023-04-14T00:19:30         50
# 98            64381a0cf41ad160d023ba29  2023-04-14T00:08:13         50
# 98            64381a0cf41ad160d023ba29  2023-04-14T00:08:13         50
# 99            6438178fa60ed958fbf52bf8  2023-04-14T00:04:14         50
# 99            6438178fa60ed958fbf52bf8  2023-04-14T00:04:14         50
#
#                                                       matchInfo
# change_index
# ...

# %%
match_info_data = match_HOJJIMIN.iloc[:, [0,1,2]].reset_index(drop = True)
accessId_data = pd.DataFrame(accessId_list)
nickname_data = pd.DataFrame(nickname_list)

match_detail_data = pd.DataFrame(matchDetail_list)
match_shoot_data = pd.DataFrame(shootDetail_list)
match_pass_data = pd.DataFrame(passDetail_list)
match_defence_data = pd.DataFrame(defenceDetail_list)

print('Shape of match_info_data : ', match_info_data.shape)
print('Shape of accessId_data : ', accessId_data.shape)
print('Shape of nickname_data : ', nickname_data.shape)
print('Shape of match_detail_data : ', match_detail_data.shape)
print('Shape of match_shoot_data : ', match_shoot_data.shape)
print('Shape of match_pass_data : ', match_pass_data.shape)
print('Shape of match_defence_data : ', match_defence_data.shape)
# Out:
# Shape of match_info_data :  (200, 3)
# Shape of accessId_data :  (200, 1)
# Shape of nickname_data :  (200, 1)
# Shape of match_detail_data :  (200, 14)
# Shape of match_shoot_data :  (200, 16)
# Shape of match_pass_data :  (200, 14)
# Shape of match_defence_data :  (200, 4)

# %%
accessId_data = accessId_data.rename(columns={0 : 'accessId'}) # 컬럼명 변경
nickname_data = nickname_data.rename(columns={0 : 'nickname'}) # 컬럼명 변경

display(accessId_data.head(), nickname_data.head())
# Out:
#                    accessId
# 0  2e79630544e8b60b4e280106
# 1  3cdf995d54068517228c31cd
# 2  3cdf995d54068517228c31cd
# 3  e7442b8debde3fbc6b39befe
# 4  3cdf995d54068517228c31cd
#    nickname
# 0    낭만낭만낭만
# 1    챔피언스국대
# 2    챔피언스국대
# 3  텐하흐샴푸뭐쓰냐
# 4    챔피언스국대

# %%
display(match_detail_data.head(), match_shoot_data.head(), match_pass_data.head(),
match_defence_data.head())
# Out:
#    seasonId matchResult  matchEndType  systemPause  foul  injury  redCards  \
# 0    202305           패             0            1     0       0         0
# 1    202305           승             0            0     1       1         0
# 2    202305           패             0            0     4       0         0
# 3    202305           승             0            0     0       0         0
# 4    202305           승             0            0     1       0         0
#
#    yellowCards  dribble  cornerKick  possession  offsideCount  averageRating  \
# 0            0       91           0          60             0        3.70556
# 1            1       67           0          40             0        4.17222
# 2            0       60           1          43             1        3.78333
# 3            0       98           4          57             1        4.58889
# 4            1       61           1          49             1        4.65000
#
#   controller
# 0   keyboard
# 1   keyboard
# ...

# %%
match_data = pd.concat([match_info_data, accessId_data, nickname_data, match_detail_data, match_shoot_data, match_pass_data, match_defence_data], axis = 1)

# %%
match_data.head()
# Out:
#                     matchId            matchDate  matchType  \
# 0  6463880b82e1730114777f16  2023-05-16T22:51:22         50
# 1  6463880b82e1730114777f16  2023-05-16T22:51:22         50
# 2  646239e2206717b7ae7ac23d  2023-05-15T23:07:10         50
# 3  646239e2206717b7ae7ac23d  2023-05-15T23:07:10         50
# 4  6460dbfd9fbc18bd9c7b47b9  2023-05-14T22:13:28         50
#
#                    accessId  nickname  seasonId matchResult  matchEndType  \
# 0  2e79630544e8b60b4e280106    낭만낭만낭만    202305           패             0
# 1  3cdf995d54068517228c31cd    챔피언스국대    202305           승             0
# 2  3cdf995d54068517228c31cd    챔피언스국대    202305           패             0
# 3  e7442b8debde3fbc6b39befe  텐하흐샴푸뭐쓰냐    202305           승             0
# 4  3cdf995d54068517228c31cd    챔피언스국대    202305           승             0
#
#    systemPause  foul  injury  redCards  yellowCards  dribble  cornerKick  \
# 0            1     0       0         0            0       91           0
# ...

# %%
with open('C:/Users/goeunseong/Desktop/Python/개인 프로젝트/피파온라인4 데이터 분석/match_data.pkl', 'wb') as f: # 완성된 데이터프레임 pickle 형태로 저장
    pickle.dump(match_data, f)

# %%
with open('C:/Users/goeunseong/Desktop/Python/개인 프로젝트/피파온라인4 데이터 분석/match_data.pkl', 'rb') as f: # pickle 데이터 부르기
    my_match = pickle.load(f)

# %%
my_match.to_csv('C:/Users/goeunseong/Desktop/Python/개인 프로젝트/피파온라인4 데이터 분석/match_data.csv', encoding='utf-8', index=False)
